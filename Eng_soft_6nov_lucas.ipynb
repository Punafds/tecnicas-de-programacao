# %% [markdown]
# <a href="https://colab.research.google.com/github/Punafds/tecnicas-de-programacao/blob/main/Eng_soft_6nov_lucas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Operadores

# %%
2**3
# Out:
# 8

# %%
23 // 7
# Out:
# 3

# %%
23 % 7
# Out:
# 2

# %%
5+5/5*5
# Out:
# 10.0

# %%
4 ** (4 / 2) + 7
# Out:
# 23.0

# %%
a=int (input(" infomre o numero: "))
b=int(input(" informe o numero: " ))
print(a+b)
# Out:
#  infomre o numero: 3
#  informe o numero: 4
# 7

# %%
nota1 =5
nota2 = 7
media_aritmetica = (nota1 + nota2)/2
print(media_aritmetica)
# Out:
# 6.0

# %%
nome = 'lucas'

print('ola, ' + nome + '!')
print('ola, ', nome + '!')
print('ola, ', nome + '!', sep=',  ')
print('ola, ', nome + '!', sep=', ', end='!')

print('ola,{}!'.format(nome) )
print(f'ola, {nome}!')
# Out:
# ola, lucas!
# ola,  lucas!
# ola, ,  lucas!
# ola, , lucas!!ola,lucas!
# ola, lucas!

# %%
print('digite seu nome: ')
nome = input()

print(f'ola, {nome}!')
# Out:
# digite seu nome:
# lucas
# ola, lucas!

# %%
print('digite seu nome: ')
nome_usuario = input()
print('digite seu ano de nascimento: ')
ano_nascimento = input()

print(f'seu nome é {nome_usuario} e voce nasceu em {ano_nascimento}!')
# Out:
# digite seu nome:
# lucas
# digite seu ano de nascimento:
# 2006
# seu nome é lucas e voce nasceu em 2006!

# %%
print('digite seu nome: ')
nome_usuario = input()

print('digite seu ano de nascimento: ')
ano_nascimento_numero = input()
ano_nascimento = int(ano_nascimento_numero)

print('digite o ano atual: ')
ano_atual = int(input())

idade = ano_atual - ano_nascimento

print(f'Olá, {nome_usuario}! Você tem {idade} anos ')

print(f'Ano de nascimento: {ano_nascimento_numero}')

print(nome_usuario * idade)
# Out:
# digite seu nome:
# lcuas
# digite seu ano de nascimento:
# 2006
# digite o ano atual:
# 2025
# Olá, lcuas! Você tem 19 anos
# Ano de nascimento: 2006
# lcuaslcuaslcuaslcuaslcuaslcuaslcuaslcuaslcuaslcuaslcuaslcuaslcuaslcuaslcuaslcuaslcuaslcuaslcuas

# %%
print('Digite a primeira nota:')
nota1 = float(input())

print('Digite a segunda nota:')
nota2 = float(input())

print('Digite a terceira nota:')
nota3 = float(input())

media_ponderada = (nota1 + nota2 + nota3) / 3

print(f'A média ponderada é: {media_ponderada}')
# Out:
# Digite a primeira nota:
# 3
# Digite a segunda nota:
# 5
# Digite a terceira nota:
# 6
# A média ponderada é: 4.666666666666667

# %%
print('Digite a primeira nota:')
nota1 = float(input())
print('Digite o peso da primeira nota:')
peso1 = float(input())

print('Digite a segunda nota:')
nota2 = float(input())
print('Digite o peso da segunda nota:')
peso2 = float(input())

print('Digite a terceira nota:')
nota3 = float(input())
print('Digite o peso da terceira nota:')
peso3 = float(input())

media_ponderada = (nota1 * peso1 + nota2 * peso2 + nota3 * peso3) / (peso1 + peso2 + peso3)

print(f'A média ponderada é: {media_ponderada}')
# Out:
# Digite a primeira nota:
# 10
# Digite o peso da primeira nota:
# 5
# Digite a segunda nota:
# 5
# Digite o peso da segunda nota:
# 5
# Digite a terceira nota:
# 6
# Digite o peso da terceira nota:
# 7
# A média ponderada é: 6.882352941176471

# %%
print('Digite um número:')
numero = input()
soma = 0
for digito in numero:
  soma += int(digito)

print(f'A soma dos dígitos é: {soma}')
# Out:
# Digite um número:
# 5
# A soma dos dígitos é: 5

# %%
print('Digite uma palavra:')
palavra = input()

palavra_invertida = palavra[::-1]

print(f'A palavra invertida é: {palavra_invertida}')
# Out:
# Digite uma palavra:
# lucas
# A palavra invertida é: sacul
